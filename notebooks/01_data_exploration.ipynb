# %%
# notebooks/01_data_exploration.ipynb
from datasets import load_dataset

# SROIE 2019 receipts (987 annotated receipt images)
sroie = load_dataset("jsdnrs/ICDAR2019-SROIE")

# FUNSD form-understanding dataset
funsd = load_dataset("nielsr/funsd")

# Save to root data/raw/
sroie.save_to_disk("../data/raw/sroie")
funsd.save_to_disk("../data/raw/funsd")
# Out:
# ...
# Saving the dataset (1/1 shards): 100%|██████████| 50/50 [00:00<00:00, 5556.84 examples/s]
